# %%
from requests import api

# %%
query = <your query>

# %%
r = api.get('http://127.0.0.1:8000/search/', params={"q": query})
r
# Out:
# <Response [200]>

# %%
r.text
# Out:
# '[{"title":"Django Unchained - Wikipedia","href":"https://en.wikipedia.org/wiki/Django_Unchained","body":"Django Unchained is a 2012 American revisionist Western film written and directed by Quentin Tarantino. Produced by Tarantino\'s A Band Apart and Columbia ..."},{"title":"Django (character)","href":"https://grokipedia.com/page/Django_(character)","body":"Franco Nero as Django)Django is the titular protagonist of the 1966 Italian Spaghetti Western film Django, directed by Sergio Corbucci and portrayed by Franco Nero in his..."},{"title":"Django: The web framework for perfectionists with deadlines","href":"https://www.djangoproject.com/","body":"Django is a high-level Python web framework that encourages rapid development and clean, pragmatic design."},{"title":"Download Django","href":"https://www.djangoproject.com/download/","body":"How to get Django. Django is available open-source under the BSD license. We recommend using the latest version of Python. See the FAQ for the Python
# ...
