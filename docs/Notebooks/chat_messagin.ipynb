# %%
from requests import api

# %%
r = api.post("http://127.0.0.1:8000/ai/create-chat", json= {
    "message": "Selam naberssss "
})

# %%
data = r.json()

# %%
chat_id = data.get('chat_id')
chat_title = data.get('title')

# %%
chat_id
# Out:
# '6972033146c199a16fc845af'

# %%
chat_title
# Out:
# 'Selam Naberssss'

# %%
r = api.get('http://127.0.0.1:8000/ai/chat/6971e4d6c9eaeb5f953a8fa8/history')

# %%
r.json()
# Out:
# {'chat_id': '6971e4d6c9eaeb5f953a8fa8',
#  'history': [{'_id': '6972079981a2a7ad06b90549',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'user',
#    'content': 'Selam test mesajı bu',
#    'created_at': '2026-01-22T11:18:49.665000'},
#   {'_id': '6972079d81a2a7ad06b9054a',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'ai',
#    'content': 'Selam — test mesajını aldım. Her şey çalışıyor. Başka denemek veya devam etmek istediğin bir şey var mı?',
#    'created_at': '2026-01-22T11:18:53.476000'},
#   {'_id': '697207a481a2a7ad06b9054b',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'user',
#    'content': 'harika ',
#    'created_at': '2026-01-22T11:19:00.574000'},
#   {'_id': '697207ae81a2a7ad06b9054c',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'ai',
#    'content': 'Sevindim! Yardım edebileceğim başka bir şey var mı—RAG aramasını tekrar deneyeyim mi yoksa başka bir konuya geçelim mi?',
#    'created_at': '2026-01-22T11:19:10.378000'},
#   {'_id': '697207ce81a2a7ad06b9054d',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'user',
#    'content': 'Selam test mesajı bu',
#    'created_at': '2026-01-22T11:19:42.584000'},
#   {'_id': '697207d181a2a7ad06b9054e',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'user',
#    'content': 'Selam test mesajı bu',
#    'created_at': '2026-01-22T11:19:45.577000'},
#   {'_id': '697207d281a2a7ad06b9054f',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'ai',
#    'content': 'Aldım — test mesajını kaydettim. Her şey çalışıyor. Başka bir test veya yardım ister misin?',
#    'created_at': '2026-01-22T11:19:46.351000'},
#   {'_id': '697207d281a2a7ad06b90550',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'user',
#    'content': 'Selam test mesajı bu',
#    'created_at': '2026-01-22T11:19:46.692000'},
#   {'_id': '697207d581a2a7ad06b90551',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'ai',
#    'content': 'Aldım — test mesajını kaydettim. Her şey çalışıyor. Başka bir şey denemek veya devam etmek ister misin?',
#    'created_at': '2026-01-22T11:19:49.899000'},
#   {'_id': '697207d781a2a7ad06b90552',
#    'SessionId': '6971e4d6c9eaeb5f953a8fa8',
#    'role': 'ai',
#    'content': 'Aldım — test mesajın kaydedildi. Hazırım, başka bir test veya devam etmek istediğin bir şey var mı?',
#    'created_at': '2026-01-22T11:19:51.750000'}]}

# %%
r = api.get('http://127.0.0.1:8000/ai/chats?user_id=pars')

# %%
r.json()
# Out:
# {'chats': [{'user_id': 'pars',
#    'title': 'S Chat',
#    'created_at': '2026-01-22T12:50:38.306000',
#    'updated_at': '2026-01-22T12:50:38.306000',
#    'message_count': 0,
#    'chat_id': '6971f2eec9eaeb5f953a8fa9'},
#   {'user_id': 'pars',
#    'title': 'Video Bilgisi Türkçe Açıklama',
#    'created_at': '2026-01-22T12:56:59.090000',
#    'updated_at': '2026-01-22T09:59:27.397000',
#    'message_count': 2,
#    'chat_id': '6971f46bc9eaeb5f953a8fab'},
#   {'user_id': 'pars',
#    'title': 'Video İçeriği Türkçe TTS',
#    'created_at': '2026-01-22T11:50:30.113000',
#    'updated_at': '2026-01-22T09:33:55.814000',
#    'message_count': 22,
#    'chat_id': '6971e4d6c9eaeb5f953a8fa8'},
#   {'user_id': 'pars',
#    'title': 'Video Bilgisi Türkçe Açıklama',
#    'created_at': '2026-01-21T11:18:36.519000',
#    'updated_at': '2026-01-21T23:18:44.234000',
#    'message_count': 34,
#    'chat_id': '69708bdc4f04da701514a261'},
#   {'user_id': 'pars',
#    'title': 'Video Bilgisi TTS Açıklaması',
#    'created_at': '2026-01-21T11:23:04.034000',
#    'updated_at': '2026-01-21T08:29:37.976000',
#    'message_count': 4,
#    'chat_id': '69708ce891077318aedde631'},
#   {'user_id': 'pars',
#    'title': 'Video Bilgisi Türkçe Açıklama',
#    'created_at': '2026-01-20T22:49:14.535000',
#    'updated_at': '2026-01-20T22:49:14.535000',
#    'message_count': 0,
#    'chat_id': '696fdc3a7f3cbc9197fbeb70'},
#   {'user_id': 'pars',
#    'title': 'Izmir Cat Research Summary',
#    'created_at': '2026-01-20T22:35:17.299000',
#    'updated_at': '2026-01-20T22:35:17.299000',
#    'message_count': 0,
#    'chat_id': '696fd8f5c31f045c8efead8b'},
#   {'user_id': 'pars',
#    'title': 'Izmir Kedisi Hakkında Özet',
#    'created_at': '2026-01-20T22:31:46.045000',
#    'updated_at': '2026-01-20T22:31:46.045000',
#    'message_count': 0,
#    'chat_id': '696fd822116612b83fe8f8c6'},
#   {'user_id': 'pars',
#    'title': 'Video Bilgisi Türkçe Açıklama',
#    'created_at': '2026-01-20T23:01:00.658000',
#    'updated_at': '2026-01-20T20:02:18.738000',
#    'message_count': 2,
#    'chat_id': '696fdefca33ef0939252a44b'},
#   {'user_id': 'pars',
#    'title': 'Izmir Cat Research Summary',
#    'created_at': '2026-01-20T19:55:17.617000',
#    'updated_at': '2026-01-20T19:55:17.617000',
#    'message_count': 0,
#    'chat_id': '696fb375ce1d4b6c0d132c31'},
#   {'user_id': 'pars',
#    'title': 'İzmir Kedisi Araştırma Özet',
#    'created_at': '2026-01-20T22:43:14.171000',
#    'updated_at': '2026-01-20T19:46:32.460000',
#    'message_count': 6,
#    'chat_id': '696fdad27f3cbc9197fbeb6f'},
#   {'user_id': 'pars',
#    'title': 'İzmir Kedisi Hakkında Özet',
#    'created_at': '2026-01-20T22:36:32.745000',
#    'updated_at': '2026-01-20T19:37:23.917000',
#    'message_count': 2,
#    'chat_id': '696fd940c442ff72f77ae098'},
#   {'user_id': 'pars',
#    'title': 'Izmir Kedisi Araştırma Özeti',
#    'created_at': '2026-01-20T22:29:31.419000',
#    'updated_at': '2026-01-20T19:30:43.802000',
#    'message_count': 2,
#    'chat_id': '696fd79b6f761facb79e91c9'},
#   {'user_id': 'pars',
#    'title': 'İzmir Kedisi Araştırma Özeti',
#    'created_at': '2026-01-20T19:56:28.073000',
#    'updated_at': '2026-01-20T19:29:08.334000',
#    'message_count': 2,
#    'chat_id': '696fb3bc2a8f0c320f9cced0'},
#   {'user_id': 'pars',
#    'title': 'Dosya Analiz Talebi',
#    'created_at': '2026-01-20T14:58:24.354000',
#    'updated_at': '2026-01-20T14:58:24.354000',
#    'message_count': 0,
#    'chat_id': '696f6de09669f6ccc2d4de03'},
#   {'user_id': 'pars',
#    'title': 'Video Summary T58xJ4A34JM',
#    'created_at': '2026-01-20T17:40:28.395000',
#    'updated_at': '2026-01-20T14:54:42.289000',
#    'message_count': 8,
#    'chat_id': '696f93dcf2fec5c467653e70'},
#   {'user_id': 'pars',
#    'title': 'Python Django Web Search',
#    'created_at': '2026-01-20T15:48:26.459000',
#    'updated_at': '2026-01-20T14:17:49.911000',
#    'message_count': 20,
#    'chat_id': '696f799af83613d379093a7d'},
#   {'user_id': 'pars',
#    'title': 'Django Web Search Overview',
#    'created_at': '2026-01-20T15:29:06.884000',
#    'updated_at': '2026-01-20T12:35:52.308000',
#    'message_count': 6,
#    'chat_id': '696f75129ae958837e94301d'},
#   {'user_id': 'pars',
#    'title': 'Python Django Web Search Summary',
#    'created_at': '2026-01-20T15:13:16.879000',
#    'updated_at': '2026-01-20T12:28:39.723000',
#    'message_count': 12,
#    'chat_id': '696f715cd35b1d006bf85386'},
#   {'user_id': 'pars',
#    'title': 'Analyze This File',
#    'created_at': '2026-01-20T14:59:08.893000',
#    'updated_at': '2026-01-20T12:12:52.769000',
#    'message_count': 14,
#    'chat_id': '696f6e0cea9f20ef8e60f0fa'}]}

# %% [markdown]
# ---

# %%
import requests
import json

url = f"http://127.0.0.1:8000/ai/chat/{chat_id}"
def ask(_ask: str, prompt: str = ''):
    with requests.post(
        url,
        data={
            "question": _ask,
        },
        stream=True,
        timeout=60
    ) as r:
        if r.status_code != 200:
            print(r.text)
        r.raise_for_status()
    
        for line in r.iter_lines(decode_unicode=True):
            if not line:
                continue
    
            if line.startswith("data:"):
                chunk = line.removeprefix("data:").strip()
    
                if chunk == "[DONE]":
                    break
                
                ch = json.loads(chunk) 
                if ch.get('type') == 'tool_start':
                    print('Start:', ch.get('tool'), 'q: ', ch.get('input'))
                    print('\n')
                
                if ch.get('type') == 'tool_end':
                    print('End:', ch.get('tool'))
                    print('\n')
                
                print(ch.get('content'), end="", flush=True)

# %%
ask(
    "bu video daki bilgiyi bana türkçe açıkla açıklaman bir tts modeline verilip seslendirilecek buna dikkat ederek yazarsan sevinirim https://www.youtube.com/watch?v=zsPD9aohymw"
)
# Out:
# Aşağıdaki metin doğrudan bir TTS modeline verilip seslendirilmeye uygundur. Cümleleri kısa ve net tuttum; akıcılık ve anlaşılabilirlik için konuşma ritmine uygun paragraflar halinde düzenledim.
#
# Metin:
# Bu video 2026 için en faydalı beş programlama dilini sıralıyor. Kriterler: gerçek üretimde kullanım, işe alım durumu ve yapay zekânın hangi becerileri güçlendirdiği. Şimdi diller ve nedenleriyle kısaca anlatıyorum.
#
# Bir: TypeScript. Modern uygulamaların varsayılan dilidir. GitHub verileri TypeScript’in katkıcı sayısında hızlı bir büyüme gösterdiğini söylüyor. TypeScript sadece ön uçta değil. Arka uçta, iç araçlarda, geliştirici araçlarında ve AI ürünlerinde de yaygın kullanılıyor. AI arayüz kodu üretebilir, ama durum yönetimi, veri modelleri ve mimari kararlar gibi karmaşık konularda insan uzmanlığı hâlâ gerekli. TypeScript bilen kişi tek başına bir uygulamayı baştan sona kurup yönetebilir.
#
# İki: Python. Çok geniş bir kullanım alanına sahip. AI, veri iş akışları, otomasyon ve iç araçlarda genellikle Python kullanılır. Ağır hesaplamalar başka dillerde olsa bile Python üst katta orkestrasyon görevini yapar. Ancak Python artık daha yaygın; bu yüzden Python’u başka bir uzmanlıkla birleştirmek avantaj sağlar. Öğrenirken projeler yaparak aktif öğrenin; bu kalıcı öğrenmeyi artırır.
#
# Üç: Go. Bulut altyapısı, DevOps araçları ve yüksek verimli arka uç servislerinde güçlüdür. Go rolleri genelde daha az başvuru alır ama sorumluluklar ve beklentiler yüksektir. Bu yüzden maaşlar ve pozisyon kalitesi genelde iyi olur. Altyapı, platform mühendisliği veya yüksek ölçekli servislerle ilgileniyorsanız Go iyi bir yatırım olabilir.
#
# Dört: Rust. Bellek güvenliği, performans ve güvenlik gerektiren sistemlerde tercih edilir. Geliştiriciler arasında çok beğeniliyor ve şirketler Rust’ı bilinçli olarak benimsiyor. Rust, düşük seviyede doğruluk ve güvenlik sunduğu için AI ile kolayca taklit edilemeyen bir uzmanlık sağlar. Uzun vadede güçlü bir tercih olarak değerlendirilebilir.
#
# Beş: Java ve C#. Kurumsal yazılımlar, bankacılık ve büyük ölçekli sistemler hâlâ bu dilleri yoğun kullanıyor. Bu alanlar AI tarafından kolayca ortadan kalkmıyor. Eğer istikrarlı, kurumsal işlerde çalışmak istiyorsanız Java veya C# bilmek size geniş kapılar açar. Özellikle yeni başlayanlar bu dillerle daha kolay öne çıkabilir.
#
# Sonuç ve tavsiye: Çok sayıda dili yüzeysel öğrenmekten kaçının. Tek bir ana dil seçin ve derinleşin. Buna ek olarak bir niş veya tamamlayıcı uzmanlık edinin. 2026’da derinlik, yüzeyselliğe göre daha değerli olacak.
#
# Kaynak: Bu özet, verdiğiniz YouTube videosundan derlenmiştir. Videoda anılan veri kaynakları arasında GitHub Octoverse, Stack Overflow anketleri ve TIOBE endeksi yer alır. Orijinal video: https://www.youtube.com/watch?v=zsPD9aohymw
#
# İsterseniz metni daha kısa, daha uzun veya farklı bir seslendirme hızına göre yeniden düzenleyebilirim. Hangi uzunluk veya ton istersiniz?None

# %%
ask(
    "tşekürler"
)
# Out:
# Rica ederim! Başka bir konuda yardımcı olabilir miyim?None
